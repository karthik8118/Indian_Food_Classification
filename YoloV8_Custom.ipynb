# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
root_dir = '/content/gdrive/MyDrive/indian_food_classification.v1i.yolov8'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 10.0 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO

#load a model
model = YOLO("yolov8n.yaml")

#use thr model
results = model.train(data=os.path.join(root_dir, "data.yaml"), epochs = 75)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/indian_food_classification.v2i.yolov8'
# Out:
# cp: cannot stat '/content/runs': No such file or directory

# %%
# !yolo task=detect  mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source=/content/gdrive/MyDrive/indian_food_classification.v2i.yolov8/test/images
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/4 /content/gdrive/MyDrive/indian_food_classification.v1i.yolov8/test/images/biriyanitrain-11-_jpg.rf.7b7ba17b4851196a70475cfcd908edc3.jpg: 640x640 1 biriyani_dish, 367.0ms
# image 2/4 /content/gdrive/MyDrive/indian_food_classification.v1i.yolov8/test/images/biriyanitrain-26-_jpg.rf.e82f7d28f1e76ba9a8061f47a1be5a62.jpg: 640x640 1 biriyani_dish, 552.1ms
# image 3/4 /content/gdrive/MyDrive/indian_food_classification.v1i.yolov8/test/images/biriyanitrain-32-_jpg.rf.86cf8be3f7a48e55c986c2677b4cfaf3.jpg: 640x640 1 biriyani_dish, 195.4ms
# image 4/4 /content/gdrive/MyDrive/indian_food_classification.v1i.yolov8/test/images/biriyanitrain-58-_jpg.rf.84d109bdd8d9fe91ed0a5482fe6222a4.jpg: 640x640 1 biriyani_dish, 181.8ms
# Speed: 4.6ms preprocess, 324.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ...
